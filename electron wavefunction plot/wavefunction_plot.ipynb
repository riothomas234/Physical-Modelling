# %%
# Importing needed libraries (will be used throughout the notebook)
import numpy as np
import matplotlib.pyplot as plt
from numpy import pi

# Set font for labels in coming figures
font16 = {'family': 'serif',
          'color':  'black',
          'weight': 'normal',
          'size': 16,
          }

# Set font for labels in coming figures
font20 = {'family': 'serif',
          'color':  'black',
          'weight': 'normal',
          'size': 20,
          }


x= np.arange(-3.5,3.5, 0.1)

plt.title("wavefunction", fontdict = font20)
plt.xticks(np.arange(-4, 4, step=1),fontsize=16,fontfamily='serif') # style={'normal', 'italic', 'oblique'}
plt.yticks(np.arange(0., 1.4, step=0.4),fontsize=16,fontfamily='serif')
plt.xlabel('$x$', fontdict=font16)
plt.ylabel('$psi$', fontdict=font16)
for t in range(-1,2):
  psi =np.sin(2*pi*(x-t))/(2*pi*(x-t))

  plt.plot(x,psi)




plt.legend(["t=-1","t=0","t=1"])
plt.show()


t=0
psi_b_0= 0.5*(np.sin(2*pi*(x-t))/(2*pi*(x-t))+np.sin(2*pi*(x+t))/(2*pi*(x+t)))
plt.plot(x,psi_b_0)

t=0.6
psi_b_1= 0.5*(np.sin(2*pi*(x-t))/(2*pi*(x-t))+np.sin(2*pi*(x+t))/(2*pi*(x+t)))
plt.plot(x,psi_b_1)

t=1.8
psi_b_2= 0.5*(np.sin(2*pi*(x-t))/(2*pi*(x-t))+np.sin(2*pi*(x+t))/(2*pi*(x+t)))
plt.plot(x,psi_b_2)

plt.legend(["t=0","t=0.6","t=1.8"])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from numpy import pi
from mpl_toolkits.mplot3d import Axes3D

# Set font for labels in coming figures
font16 = {'family': 'serif',
          'color':  'black',
          'weight': 'normal',
          'size': 16,
          }

# Set font for labels in coming figures
font20 = {'family': 'serif',
          'color':  'black',
          'weight': 'normal',
          'size': 20,
          }

x= np.arange( -1.5, 1.5, 0.1)
t= np.arange( -0.5 , 2.5, 0.1)
xx, tt = np.meshgrid(x,t)

psi= 0.5*(np.sin(2*pi*(xx-tt))/(2*pi*(xx-tt))+np.sin(2*pi*(xx+tt))/(2*pi*(xx+tt)))
plt.axes().set_aspect('equal') # sets aspect ratio of plot
plt.title('wave progression', fontdict=font16)
plt.xlabel('$x$', fontdict=font16)
plt.ylabel('$t$', fontdict=font16)
plt.xticks(np.arange(-2, 2, step=0.5),fontsize=16,fontfamily='serif') # style={'normal', 'italic', 'oblique'}
plt.yticks(np.arange(-1, 3, step=0.5),fontsize=16,fontfamily='serif')
plt.contourf(x,t,psi, levels=15, cmap='plasma')
plt.show()


plt.contour(x,t,psi, levels=15, cmap='plasma')
plt.title('wave progression', fontdict=font16)
plt.xlabel('$x$', fontdict=font16)
plt.ylabel('$t$', fontdict=font16)
plt.savefig('empty_contours.pdf',format='pdf')
plt.show()



plt.title('singlewave progression', fontdict=font16)
plt.xlabel('$x$', fontdict=font16)
plt.ylabel('$t$', fontdict=font16)
x= np.arange( -3.5, 3.5, 0.1)
t= np.arange( 0 , 1.8, 0.1)
xx, tt = np.meshgrid(x,t)
psi= 0.5*(np.sin(2*pi*(xx-tt))/(2*pi*(xx-tt)))
plt.contourf(x,t,psi, levels=15, cmap='plasma')
plt.show()
# Out:
# <ipython-input-2-dc4714c1417a>:25: RuntimeWarning: invalid value encountered in divide
#   psi= 0.5*(np.sin(2*pi*(xx-tt))/(2*pi*(xx-tt))+np.sin(2*pi*(xx+tt))/(2*pi*(xx+tt)))

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from numpy import pi
from mpl_toolkits.mplot3d import Axes3D
x= np.arange( -1.5, 1.5, 0.1)
t= np.arange( -0.5 , 2.5, 0.1)
xx, tt = np.meshgrid(x,t)

psi= 0.5*(np.sin(2*pi*(xx-tt))/(2*pi*(xx-tt))+np.sin(2*pi*(xx+tt))/(2*pi*(xx+tt)))



# Set font for labels in coming figures
font16 = {'family': 'serif',
          'color':  'black',
          'weight': 'normal',
          'size': 16,
          }

# Set font for labels in coming figures
font20 = {'family': 'serif',
          'color':  'black',
          'weight': 'normal',
          'size': 20,
          }


ax = plt.axes(projection='3d')
ax.plot_surface(xx,tt,psi, cmap=cm.plasma)
# Controlling appearance of ticks and labels
plt.xticks(np.arange(-2, 2, step=1),fontsize=16,fontfamily='serif') # style={'normal', 'italic', 'oblique'}
plt.yticks(np.arange(-1, 3, step=1),fontsize=16,fontfamily='serif')
plt.xlabel('x',fontdict=font16)
ax.set_zticks(np.arange(-0.2, 1.2, 0.2))
plt.ylabel('t',fontdict=font16)
ax.set_zlabel('$z$', rotation=180) # plt.zlabel('z')
plt.title('wavefunction',fontdict=font20)
ax.view_init(60, 90)
fig1 = plt.figure()

plt.show()




x= np.arange( -1.5, 1.5, 0.1)
t= np.arange( -0.5 , 2.5, 0.1)
xx, tt = np.meshgrid(x,t)

psi= 0.5*(np.sin(2*pi*(xx-tt))/(2*pi*(xx-tt))+np.sin(2*pi*(xx+tt))/(2*pi*(xx+tt)))




ax = plt.axes(projection='3d')
plt.xlabel('x',fontdict=font16)
plt.ylabel('t',fontdict=font16)
ax.set_zlabel('$z$', rotation=180)
plt.title('wavefunction',fontdict=font20)

ax.plot_wireframe(xx,tt,psi)
ax.view_init(60, 90)
fig = plt.figure()
plt.show()
# Out:
# <ipython-input-3-adef14474d6c>:10: RuntimeWarning: invalid value encountered in divide
#   psi= 0.5*(np.sin(2*pi*(xx-tt))/(2*pi*(xx-tt))+np.sin(2*pi*(xx+tt))/(2*pi*(xx+tt)))
# <ipython-input-3-adef14474d6c>:51: RuntimeWarning: invalid value encountered in divide
#   psi= 0.5*(np.sin(2*pi*(xx-tt))/(2*pi*(xx-tt))+np.sin(2*pi*(xx+tt))/(2*pi*(xx+tt)))
